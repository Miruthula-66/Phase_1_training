# %%
df = spark.read.csv("/FileStore/tables/matches.csv", header=True, inferSchema=True)

# %%
selected_df = df.select("id", "season", "city")

# %%
selected_df.show(5)
# Out:
# +------+-------+----------+
# |    id| season|      city|
# +------+-------+----------+
# |335982|2007/08| Bangalore|
# |335983|2007/08|Chandigarh|
# |335984|2007/08|     Delhi|
# |335985|2007/08|    Mumbai|
# |335986|2007/08|   Kolkata|
# +------+-------+----------+
# only showing top 5 rows

# %%
display(selected_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
